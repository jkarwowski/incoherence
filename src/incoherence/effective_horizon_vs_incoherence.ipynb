# %%
import matplotlib.pyplot as plt

# %%
# === Environment: two_cards ===
# Estimated effective horizon H_hat: 2.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.483, 2: 0.488, 4: 0.434, 8: 0.441, 16: 0.416, 32: 0.366}
#   k=2: best_m=1, H_k=2.000, probs={1: 0.554}
#   k=3: best_m=1, H_k=3.000, probs={1: 0.544}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.422579
#   κδ(π^G_1 = G(p)) = 0.037591
#   J(uniform)      = 2.5202
#   J(π^G_1)        = 2.8032
#   J* (optimal)    = 3.0000
# Trying 0
# 0 failed
# Trying 1
# 1 success
# Trying 2
# 2 success
# Trying 3
# 3 success
# /Users/jacski/incoherence_refactor/src/incoherence/policy.py:12: RuntimeWarning: divide by zero encountered in log
#   return np.log(x)

# === Environment: random_T4_A3_seed1 ===
# Estimated effective horizon H_hat: 5.155
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.036, 2: 0.064, 4: 0.11, 8: 0.156, 16: 0.268, 32: 0.284, 64: 0.272, 128: 0.216, 256: 0.196}
#   k=2: best_m=32, H_k=5.155, probs={1: 0.02, 2: 0.086, 4: 0.164, 8: 0.28, 16: 0.41, 32: 0.55}
#   k=3: best_m=None, H_k=inf, probs={1: 0.036, 2: 0.084, 4: 0.152, 8: 0.23, 16: 0.252, 32: 0.16, 64: 0.1, 128: 0.02, 256: 0.0}
#   k=4: best_m=128, H_k=8.417, probs={1: 0.014, 2: 0.096, 4: 0.21, 8: 0.22, 16: 0.26, 32: 0.436, 64: 0.498, 128: 0.624}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.317154
#   κδ(π^G_1 = G(p)) = 0.032258
#   J(uniform)      = 2.6203
#   J(π^G_1)        = 3.4478
#   J* (optimal)    = 4.1948

# === Environment: random_T4_A3_seed2 ===
# Estimated effective horizon H_hat: 6.155
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.014, 2: 0.048, 4: 0.09, 8: 0.148, 16: 0.23, 32: 0.328, 64: 0.43, 128: 0.492, 256: 0.498}
#   k=2: best_m=None, H_k=inf, probs={1: 0.022, 2: 0.056, 4: 0.168, 8: 0.256, 16: 0.348, 32: 0.444, 64: 0.478, 128: 0.454, 256: 0.454}
#   k=3: best_m=32, H_k=6.155, probs={1: 0.024, 2: 0.09, 4: 0.144, 8: 0.286, 16: 0.4, 32: 0.512}
#   k=4: best_m=128, H_k=8.417, probs={1: 0.026, 2: 0.068, 4: 0.166, 8: 0.276, 16: 0.342, 32: 0.432, 64: 0.48, 128: 0.582}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.400806
#   κδ(π^G_1 = G(p)) = 0.042960
#   J(uniform)      = 2.4395
#   J(π^G_1)        = 3.0702
#   J* (optimal)    = 3.7634

# === Environment: random_T4_A3_seed3 ===
# Estimated effective horizon H_hat: 6.786
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.034, 2: 0.04, 4: 0.032, 8: 0.026, 16: 0.018, 32: 0.008, 64: 0.0, 128: 0.0, 256: 0.0}
#   k=2: best_m=None, H_k=inf, probs={1: 0.02, 2: 0.034, 4: 0.034, 8: 0.05, 16: 0.014, 32: 0.012, 64: 0.0, 128: 0.0, 256: 0.0}
#   k=3: best_m=64, H_k=6.786, probs={1: 0.034, 2: 0.05, 4: 0.076, 8: 0.122, 16: 0.218, 32: 0.392, 64: 0.572}
#   k=4: best_m=None, H_k=inf, probs={1: 0.018, 2: 0.06, 4: 0.09, 8: 0.176, 16: 0.262, 32: 0.37, 64: 0.426, 128: 0.424, 256: 0.378}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.433150
#   κδ(π^G_1 = G(p)) = 0.093889
#   J(uniform)      = 2.4959
#   J(π^G_1)        = 3.1053
#   J* (optimal)    = 3.7928


# =============

# === Environment: random_T4_A3_seed5 ===
# Estimated effective horizon H_hat: 5.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=16, H_k=5.000, probs={1: 0.066, 2: 0.104, 4: 0.26, 8: 0.324, 16: 0.516}
#   k=2: best_m=16, H_k=6.000, probs={1: 0.09, 2: 0.184, 4: 0.28, 8: 0.48, 16: 0.648}
#   k=3: best_m=8, H_k=6.000, probs={1: 0.122, 2: 0.216, 4: 0.36, 8: 0.558}
#   k=4: best_m=8, H_k=7.000, probs={1: 0.086, 2: 0.22, 4: 0.384, 8: 0.588}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.700924
#   κδ(π^G_1 = G(p)) = 0.120841
#   J(uniform)      = 3.1717
#   J(π^G_1)        = 4.1089
#   J* (optimal)    = 4.6559

# === Environment: random_T4_A3_seed6 ===
# Estimated effective horizon H_hat: 5.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=16, H_k=5.000, probs={1: 0.08, 2: 0.146, 4: 0.246, 8: 0.374, 16: 0.558}
#   k=2: best_m=8, H_k=5.000, probs={1: 0.112, 2: 0.25, 4: 0.392, 8: 0.554}
#   k=3: best_m=8, H_k=6.000, probs={1: 0.142, 2: 0.278, 4: 0.466, 8: 0.614}
#   k=4: best_m=4, H_k=6.000, probs={1: 0.152, 2: 0.246, 4: 0.514}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.839659
#   κδ(π^G_1 = G(p)) = 0.019645
#   J(uniform)      = 2.7903
#   J(π^G_1)        = 3.7150
#   J* (optimal)    = 4.3650

# === Environment: random_T4_A3_seed7 ===
# Estimated effective horizon H_hat: 6.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=32, H_k=6.000, probs={1: 0.106, 2: 0.114, 4: 0.186, 8: 0.298, 16: 0.436, 32: 0.608}
#   k=2: best_m=16, H_k=6.000, probs={1: 0.088, 2: 0.19, 4: 0.25, 8: 0.38, 16: 0.606}
#   k=3: best_m=16, H_k=7.000, probs={1: 0.112, 2: 0.2, 4: 0.322, 8: 0.44, 16: 0.584}
#   k=4: best_m=16, H_k=8.000, probs={1: 0.096, 2: 0.202, 4: 0.322, 8: 0.45, 16: 0.528}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.600383
#   κδ(π^G_1 = G(p)) = 0.060826
#   J(uniform)      = 2.9244
#   J(π^G_1)        = 3.5876
#   J* (optimal)    = 4.2134


# =====



# === Environment: random_T4_A3_seed5 ===
# Estimated effective horizon H_hat: 6.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=32, H_k=6.000, probs={1: 0.046, 2: 0.078, 4: 0.154, 8: 0.248, 16: 0.452, 32: 0.758}
#   k=2: best_m=16, H_k=6.000, probs={1: 0.052, 2: 0.106, 4: 0.196, 8: 0.382, 16: 0.592}
#   k=3: best_m=None, H_k=inf, probs={1: 0.048, 2: 0.098, 4: 0.2, 8: 0.324, 16: 0.382, 32: 0.468, 64: 0.416, 128: 0.44, 256: 0.456}
#   k=4: best_m=None, H_k=inf, probs={1: 0.06, 2: 0.13, 4: 0.194, 8: 0.258, 16: 0.36, 32: 0.364, 64: 0.378, 128: 0.402, 256: 0.36}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.812605
#   κδ(π^G_1 = G(p)) = 0.061351
#   J(uniform)      = 3.5125
#   J(π^G_1)        = 4.4542
#   J* (optimal)    = 5.1758

# === Environment: random_T4_A3_seed6 ===
# Estimated effective horizon H_hat: 9.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.046, 2: 0.066, 4: 0.09, 8: 0.122, 16: 0.15, 32: 0.14, 64: 0.116, 128: 0.086, 256: 0.032}
#   k=2: best_m=None, H_k=inf, probs={1: 0.05, 2: 0.096, 4: 0.168, 8: 0.222, 16: 0.262, 32: 0.316, 64: 0.28, 128: 0.35, 256: 0.404}
#   k=3: best_m=None, H_k=inf, probs={1: 0.052, 2: 0.15, 4: 0.178, 8: 0.214, 16: 0.324, 32: 0.23, 64: 0.218, 128: 0.184, 256: 0.092}
#   k=4: best_m=32, H_k=9.000, probs={1: 0.044, 2: 0.122, 4: 0.244, 8: 0.344, 16: 0.46, 32: 0.636}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 2.476333
#   κδ(π^G_1 = G(p)) = 0.074300
#   J(uniform)      = 3.4027
#   J(π^G_1)        = 4.3506
#   J* (optimal)    = 5.1010

# === Environment: random_T4_A3_seed7 ===
# Estimated effective horizon H_hat: 7.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.046, 2: 0.068, 4: 0.08, 8: 0.122, 16: 0.18, 32: 0.182, 64: 0.212, 128: 0.214, 256: 0.18}
#   k=2: best_m=32, H_k=7.000, probs={1: 0.05, 2: 0.088, 4: 0.154, 8: 0.304, 16: 0.476, 32: 0.61}
#   k=3: best_m=16, H_k=7.000, probs={1: 0.034, 2: 0.104, 4: 0.236, 8: 0.36, 16: 0.522}
#   k=4: best_m=16, H_k=8.000, probs={1: 0.054, 2: 0.13, 4: 0.252, 8: 0.412, 16: 0.512}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.799236
#   κδ(π^G_1 = G(p)) = 0.028079
#   J(uniform)      = 3.5468
#   J(π^G_1)        = 4.5536
#   J* (optimal)    = 5.1805


# =====

# === Environment: random_T4_A3_seed8 ===
# Estimated effective horizon H_hat: 3.500
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=32, H_k=3.500, probs={1: 0.022, 2: 0.038, 4: 0.064, 8: 0.186, 16: 0.3, 32: 0.506}
#   k=2: best_m=128, H_k=5.500, probs={1: 0.014, 2: 0.042, 4: 0.078, 8: 0.144, 16: 0.218, 32: 0.336, 64: 0.384, 128: 0.53}
#   k=3: best_m=None, H_k=inf, probs={1: 0.016, 2: 0.024, 4: 0.078, 8: 0.116, 16: 0.194, 32: 0.264, 64: 0.34, 128: 0.316, 256: 0.358}
#   k=4: best_m=128, H_k=7.500, probs={1: 0.004, 2: 0.036, 4: 0.078, 8: 0.148, 16: 0.252, 32: 0.374, 64: 0.478, 128: 0.552}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 0.946930
#   κδ(π^G_1 = G(p)) = 0.034045
#   J(uniform)      = 2.0602
#   J(π^G_1)        = 2.6100
#   J* (optimal)    = 3.2456

# === Environment: random_T4_A3_seed9 ===
# Estimated effective horizon H_hat: 6.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.016, 2: 0.03, 4: 0.046, 8: 0.076, 16: 0.086, 32: 0.092, 64: 0.118, 128: 0.12, 256: 0.088}
#   k=2: best_m=None, H_k=inf, probs={1: 0.02, 2: 0.042, 4: 0.076, 8: 0.134, 16: 0.22, 32: 0.306, 64: 0.302, 128: 0.352, 256: 0.206}
#   k=3: best_m=64, H_k=6.000, probs={1: 0.022, 2: 0.032, 4: 0.1, 8: 0.146, 16: 0.318, 32: 0.474, 64: 0.692}
#   k=4: best_m=64, H_k=7.000, probs={1: 0.006, 2: 0.036, 4: 0.086, 8: 0.18, 16: 0.324, 32: 0.476, 64: 0.598}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 0.676054
#   κδ(π^G_1 = G(p)) = 0.025235
#   J(uniform)      = 1.7755
#   J(π^G_1)        = 2.1384
#   J* (optimal)    = 2.8272

# === Environment: random_T4_A3_seed10 ===
# Estimated effective horizon H_hat: 6.000
# Per-k details (k : best_m, H_k, probs(m)): 
#   k=1: best_m=None, H_k=inf, probs={1: 0.018, 2: 0.032, 4: 0.06, 8: 0.124, 16: 0.116, 32: 0.104, 64: 0.07, 128: 0.032, 256: 0.004}
#   k=2: best_m=None, H_k=inf, probs={1: 0.03, 2: 0.056, 4: 0.104, 8: 0.194, 16: 0.282, 32: 0.338, 64: 0.38, 128: 0.44, 256: 0.394}
#   k=3: best_m=64, H_k=6.000, probs={1: 0.02, 2: 0.058, 4: 0.104, 8: 0.22, 16: 0.29, 32: 0.404, 64: 0.596}
#   k=4: best_m=64, H_k=7.000, probs={1: 0.01, 2: 0.052, 4: 0.11, 8: 0.21, 16: 0.298, 32: 0.39, 64: 0.54}

# Incoherence & returns (δ=1.0 by default):
#   κδ(uniform)     = 1.042826
#   κδ(π^G_1 = G(p)) = 0.045391
#   J(uniform)      = 2.0147
#   J(π^G_1)        = 2.5759
#   J* (optimal)    = 3.1790

# %%
xyz = [(2.000, 0.037591, 1.422579),
(5.155, 0.032258, 1.317154),
(6.155, 0.042960, 1.400806),
(6.786, 0.093889, 1.433150),
(5.000, 0.120841, 1.700924),
(5.000, 0.019645, 1.839659),
(6.000, 0.060826, 1.600383),
(6.000, 0.061351, 1.812605),
(9.000, 0.074300, 2.476333),
(7.000, 0.028079, 1.799236),
(3.500, 0.034045, 0.946930),
(6.000, 0.025235, 0.676054),
(6.000, 0.045391, 1.042826),
]

# %%
x, y, z = zip(*xyz)

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,z)

# %%
import numpy as np
float(np.corrcoef(x, y)[0, 1])
# Out:
# 0.2624668401888976

# %%
import numpy as np
float(np.corrcoef(x, z)[0, 1])
# Out:
# 0.47740601572621916

# %%
# Calculate correlation coefficients
corr_xy = np.corrcoef(x, y)[0, 1]
corr_xz = np.corrcoef(x, z)[0, 1]

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot x vs y with trend line
ax1.scatter(x, y)
z1 = np.polyfit(x, y, 1)
p1 = np.poly1d(z1)
ax1.plot(x, p1(x), "r--", label=f'Correlation: {corr_xy:.3f}')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('x vs y')
ax1.legend()

# Plot x vs z with trend line
ax2.scatter(x, z)
z2 = np.polyfit(x, z, 1)
p2 = np.poly1d(z2)
ax2.plot(x, p2(x), "r--", label=f'Correlation: {corr_xz:.3f}')
ax2.set_xlabel('x')
ax2.set_ylabel('z')
ax2.set_title('x vs z')
ax2.legend()
